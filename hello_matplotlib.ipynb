# %%
# %matplotlib inline
 
import numpy as np
import matplotlib.pyplot as plt
 
def f(x):
    return (np.sin(x))/x

a = np.linspace(200,1,200)
b = (-i for i in a)
b=list(b)
b.reverse()

plt.plot(a,f(a))
plt.plot(b,f(b))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
